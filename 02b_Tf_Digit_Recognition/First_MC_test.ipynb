# %%
import numpy as np
import json
import gzip

files = ['/net/big-tank/POOL/projects/fact/simulation/photon_stream/fact_tools/v.0.18.0/output_spe_extractor_mc_55.json', '/net/big-tank/POOL/projects/fact/simulation/photon_stream/fact_tools/v.0.18.0/output_spe_extractor_mc_55.json', '/net/big-tank/POOL/projects/fact/simulation/photon_stream/fact_tools/v.0.18.0/output_spe_extractor_mc_280.json', '/net/big-tank/POOL/projects/fact/simulation/photon_stream/fact_tools/v.0.18.0/output_spe_extractor_mc_27.json']


data = []


for file in files:
    
    
    
    
    with open(file, 'r') as file:
        for elem in file:
            event = json.loads(f)['PhotonArrivals_500ps']

            input_matrix = np.zeros([1440,100])
            for i in range(1440):
                for j in l[i]:
                    input_matrix[i][j-30] += 1
            data.append(input_matrix.flatten())

# %%
print(len(data))
print(len(data[0]))
# Out:
# 1160
# 144000

# %%
file = 'v.0.18.0/gamma_werner_12/output_spe_extractor_mc_13.json.gz'

# %%
import json

# %%
import gzip
with gzip.open(file, 'rb') as f:
    elem = next(f)
    data = json.loads(elem)['PhotonArrivals_500ps']
    print(data)
# Out:
# [[129, 76], [], [48, 47], [44, 44, 75], [98], [31, 75], [75, 75, 73], [66], [], [66], [34, 108], [79, 79, 90], [102, 102], [90], [102, 101, 52], [77, 75], [66], [118, 118], [], [97, 67], [], [], [], [127, 127], [70], [98, 98, 106, 94, 106], [70], [54, 105, 62, 90, 105], [71], [41, 95, 38], [123], [50, 49, 49, 57, 48, 85, 58, 84, 96], [35, 33, 115], [87], [37, 92], [106], [], [42, 126], [71], [36, 112, 46, 58, 123], [], [70, 31], [92], [], [], [37, 63, 37], [], [125], [79, 116], [], [95], [123, 92, 122], [103], [84, 82, 86], [37, 62], [57], [121], [], [94, 40], [57, 72, 94, 121], [], [], [], [74, 32, 71, 98, 119], [92, 61, 102], [103, 48, 103], [59, 105, 59], [40, 39, 92], [111], [102], [127], [45, 124], [117], [89], [93, 109], [61, 58], [], [96], [82, 48], [53, 52], [], [122, 58, 122], [110], [], [], [35, 87, 120, 34], [34], [82, 123], [92, 104], [127], [62, 53, 67], [50, 58], [], [121, 120, 52], [102, 37, 66], [111, 107, 128], [81, 97], [109], [110], [105], [], [93, 120], [114], [52
# ...
